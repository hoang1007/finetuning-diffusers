# %%
import sys
sys.path.append('..')
import librosa
from mugen.logmel import LogMelTransform

# %%
waveform, sample_rate = librosa.load('../examples/sound2.mp3', sr=16000)
# waveform = tau.transforms.Resample(orig_freq=sample_rate, new_freq=16000)(waveform)

# %%
transform = LogMelTransform()
t = transform.transform(waveform, sampling_rate=sample_rate)

# %%
from IPython.display import Audio

Audio(waveform, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rec = transform.inv_transform(t.input_values)

# %%
Audio(rec, rate=transform.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
